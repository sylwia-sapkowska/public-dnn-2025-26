# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Program Operacyjny Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# In this lab, you will implement some of the techniques discussed in the lecture.
#
# Below you are given a solution to the previous scenario. It has two serious drawbacks:
#  * The output predictions do not sum up to one (i.e. the output is not a probability distribution), even though the images always contain exactly one digit.
#  * It uses MSE coupled with output sigmoid, which can lead to saturation and slow convergence.
#
# **Task 0.** Implement a numerically stable version of softmax.
#
# **Task 1.** Use softmax instead of coordinate-wise sigmoid and use log-loss instead of MSE. Test to see if this improves convergence. Hint: When implementing backprop it might be easier to consider these two functions as a single block, rather than compute the gradient over the softmax values.
#
# **Task 2.** Implement L2 regularization and add momentum to the SGD algorithm. Play with different amounts of regularization and momentum. See if this improves accuracy/convergence.
#
# **Task 3 (optional).** Implement Adagrad or AdamW (currently popular in LLM training), dropout, and some simple data augmentations (e.g. tiny rotations/shifts, etc.). Again, test to see how these changes improve accuracy/convergence.
#
# **Task 4.** Try adding extra layers to the network. Again, test how the changes you introduced affect accuracy/convergence. As a start, you can try this architecture: [784,100,30,10]
#
# The provided model evaluation code (`evaluate_model`) may take some time to complete. During implementation, you can change the number of evaluated models to 1 and reduce the number of tested learning rates, and epochs.

# %%
# !pip install tqdm pandas
# !wget --no-verbose -O mnist.npz https://s3.amazonaws.com/img-datasets/mnist.npz
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# 2025-11-04 11:38:06 URL:https://s3.amazonaws.com/img-datasets/mnist.npz [11490434/11490434] -> "mnist.npz" [1]

# %%
import random
import json
from pathlib import Path
from typing import Any, Callable, Sequence

import numpy as np
import pandas as pd
from IPython.display import display
from numpy.typing import NDArray
from torchvision import datasets, transforms
from tqdm import tqdm

FloatNDArray = NDArray[np.float64]

np.random.seed(42)

# %%
def load_mnist(
    path: Path = Path("mnist.npz")
) -> tuple[FloatNDArray, FloatNDArray, FloatNDArray, FloatNDArray]:
    """
    Load the MNIST dataset (grayscale 28 x 28 images of hand-written digits).

    Returns tuple of:
    - x_train: shape (N_train, H * W), grayscale values 0..1.
    - y_train: shape (N_train, 10), one-hot-encoded label, dtype float64.
    - x_test: shape (N_test, H * W), grayscale values 0..1.
    - y_train: shape (N_test, 10), one-hot-encoded label, dtype float64.

    More: https://en.wikipedia.org/wiki/MNIST_database
    """
    with np.load(path) as f:
        x_train, _y_train = f["x_train"], f["y_train"]
        x_test, _y_test = f["x_test"], f["y_test"]

    H = W = 28
    N_train = len(x_train)
    N_test = len(x_test)
    assert x_train.shape == (N_train, H, W) and _y_train.shape == (N_train,)
    assert x_test.shape == (N_test, H, W) and _y_test.shape == (N_test,)

    x_train = x_train.reshape(N_train, H * W) / 255.0
    x_test = x_test.reshape(N_test, H * W) / 255.0

    y_train = np.zeros((N_train, 10), dtype=np.float64)
    y_train[np.arange(N_train), _y_train] = 1

    y_test = np.zeros((N_test, 10))
    y_test[np.arange(N_test), _y_test] = 1

    return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = load_mnist()

# %%
def sigmoid(z: FloatNDArray) -> FloatNDArray:
    return 1.0 / (1.0 + np.exp(-z))


def sigmoid_prime(z: FloatNDArray) -> FloatNDArray:
    """Derivative of the sigmoid function."""
    return sigmoid(z) * (1 - sigmoid(z))

# %% [markdown]
# ## Warm-Up
# Implement a numerically stable version of softmax.
#
# In general, softmax is defined as
# $$\text{softmax}(x_1, x_2, \ldots, x_n) = (\frac{e^{x_1}}{\sum_i{e^{x_i}}}, \frac{e^{x_2}}{\sum_i{e^{x_i}}}, \ldots, \frac{e^{x_n}}{\sum_i{e^{x_i}}})$$
# However, taking $e^{1000000}$ can result in NaN.
# Can you implement softmax so that the highest power to which e will be risen will be at most $0$ and the predictions will be mathematically equivalent?
#
# Hint: <sub><sub><sub>sǝnlɐʌ llɐ ɯoɹɟ ʇᴉ ʇɔɐɹʇqns  puɐ ᴉ‾x ʇsǝƃɹɐl ǝɥʇ ǝʞɐʇ</sub></sub></sub>

# %%
def unstable_softmax(x: FloatNDArray, axis: int = -1) -> FloatNDArray:
    e = np.exp(x)
    return e / np.sum(e, axis=axis, keepdims=True)


def stable_softmax(x: FloatNDArray, axis: int = -1) -> FloatNDArray:
    mx = np.max(x, axis=axis, keepdims=True)
    e = np.exp(x - mx)
    return e / np.sum(e, axis=axis, keepdims=True)

### TESTS ###
def _test_one(x: FloatNDArray, y: FloatNDArray) -> None:
    r = stable_softmax(x)
    assert r.shape == y.shape, f"Expected shape {y.shape}, got {r.shape=}"
    assert np.isclose(np.ones(x.shape[0]), r.sum(axis=-1), atol=1e-5, rtol=0).all()
    assert np.isclose(y, r, atol=1e-5, rtol=0).all()

def test_stable_softmax() -> None:
    x1 = np.random.rand(100, 32).astype(np.float64)
    _test_one(x1, unstable_softmax(x1))

    x2 = np.ones((10, 10, 32), dtype=np.float64) * 1e6
    _test_one(x2, np.ones_like(x2) / x2.shape[-1])

    print("OK")

test_stable_softmax()
### TESTS END ###
# Out:
# OK

# %% [markdown]
# ## ModelResults

# %%
class ModelResults:
    """Just a helper class for gathering results in a nice table. Feel free to ignore."""
    def __init__(self):
        # Map from model name to map from lr to list of test accuracies.
        self.results = dict[str, dict[float, list[float]]]()

    def clear(self, model_name: str | None = None) -> None:
        """Forget results for a given model (defaults to all models)."""
        if model_name:
            if model_name in self.results:
                del self.results[model_name]
        else:
            self.results = {}

    def add_result(self, model_name: str, learning_rate: float, accuracy: float) -> None:
        if model_name not in self.results:
            self.results[model_name] = {}
        if learning_rate not in self.results[model_name]:
            self.results[model_name][learning_rate] = []
        self.results[model_name][learning_rate].append(accuracy)

    def display_results(self) -> None:
        data = list[dict[str, Any]]()
        for model_name, model_results in self.results.items():
            for lr, accuracies in model_results.items():
                mean_accuracy = np.mean(accuracies)
                accuracy_summary = f"{mean_accuracy:2.1%} ± {np.std(accuracies) * 100:.1f} p.p."
                data.append({
                    "model": model_name,
                    "lr": lr,
                    "mean_accuracy": mean_accuracy,
                    "accuracy": accuracy_summary
                })

        df = pd.DataFrame(data).sort_values("mean_accuracy", ascending=False)
        del df["mean_accuracy"]
        display(df.style.format({"lr": "{:.1g}"}).hide())

    def evaluate_model(
        self,
        model_name: str,
        model_constructor: Callable[[Sequence[int]], Any],
        layers: Sequence[int] = (784, 30, 10),
        learning_rates: Sequence[float] = (1.0, 10.0, 100.0),
        n_trainings: int = 3,
        **kwargs: Any
    ) -> None:
        # Automatic model name with parameters.
        if kwargs:
            if tuple(layers) != (784, 30, 10):
                model_name += "[" + ",".join(str(n) for n in layers) + "]"

            model_name += "("
            for k, v in kwargs.items():
                if isinstance(v, (float,  np.floating)):
                    model_name += f"{k}={v:.1g},"
                else:
                    model_name += f"{k}={v},"
            model_name = model_name[:-1]
            model_name += ")"

        # Train for each learning rate, n_trainings times.
        for lr in learning_rates:
            print(f"Checking {n_trainings} random trainings with with lr = {lr}")
            for i in range(n_trainings):
                network = model_constructor(layers, **kwargs)
                accuracy = network.train(
                    (x_train, y_train),
                    epochs=10,
                    mini_batch_size=100,
                    learning_rate=lr,
                    test_data=(x_test, y_test),
                )
                self.add_result(model_name, lr, float(accuracy))


model_results = ModelResults()

# %% [markdown]
# ## Baseline
# The solution to the previous lab: an MLP network with MSE loss on sigmoid outputs, trained with plain SGD (batched).

# %%
class Network:
    def __init__(self, sizes: Sequence[int] = (784, 30, 10)):
        """
        Args:
        - sizes: sequence of layer widths [N^0, ... , N^last]
          These are lengths of activation vectors, where:
          - N^0 is input size: H * W = 28 * 28 = 784.
          - N^last is the number of classes into which we can classify each input: 10.
        """
        self.sizes = list(sizes)

        # List of len(sizes) - 1 vectors of shape (N^1), (N^2), ..., (N^last).
        self.biases = [np.random.randn(n) for n in sizes[1:]]

        # List of len(sizes) - 1 matrices of shape (N^i, N^{i-1}).
        # Weights are indexed by target node first.
        self.weights = [
            np.random.randn(n_out, n_in) / np.sqrt(n_in)
            for n_in, n_out in zip(sizes[:-1], sizes[1:], strict=True)
        ]

        self.num_layers = len(self.weights)   # = len(sizes) - 1


    def feedforward(self, x: FloatNDArray) -> FloatNDArray:
        """
        Run the network on a batch of cases of shape (B, N^0), values 0..1.

        Returns last layer activations, shape (B, N^last), values 0..1.
        """
        g = x
        for w, b in zip(self.weights, self.biases, strict=True):
            # Shapes (B, N^{i-1}) @ (N^{i-1}, N^i) + (N^i,)  ==  (B, N^i)
            g = sigmoid(g @ w.T + b)
        return g

    def learning_step(self, x_mini_batch: FloatNDArray, y_mini_batch: FloatNDArray, learning_rate: float) -> None:
        """
        Update network parameters with a single mini-batch step of backpropagation and gradient descent.

        Args:
        - x_mini_batch: shape (B, N^0) where B is mini_batch_size.
        - y_mini_batch: shape (B, N^last).
        - learning_rate.
        """
        grads_w, grads_b = self.backprop(x_mini_batch, y_mini_batch)

        # Gradient descent step.
        self.weights = [
            w - learning_rate * grad_w
            for w, grad_w in zip(self.weights, grads_w, strict=True)
        ]
        self.biases = [
            b - learning_rate * grad_b
            for b, grad_b in zip(self.biases, grads_b, strict=True)
        ]

    def backprop(
        self, x: FloatNDArray, y: FloatNDArray
    ) -> tuple[list[FloatNDArray], list[FloatNDArray]]:
        """
        Backpropagation for a mini-batch (vectorized).

        Args:
        - x: input, shape (B, N^0)
        - y: target label (one-hot encoded), shape (B, N^last)

        Returns (grads_w, grads_b), where:
        - grads_w: list of gradients over weights (shape (N^i, N^{i-1})), for each layer.
        - grads_b: list of gradients over biases (shape (N^i)), for each layer.
        """
        B, N0 = x.shape
        assert N0 == self.sizes[0]
        # Values after activation function (including inputs to the first layer),
        # shapes (B, N^0), (B, N^1), ..., (B, N^last).
        gs: list[FloatNDArray] = [x]

        g = x
        for w, b in zip(self.weights, self.biases, strict=True):
            # (B, N_in) @ (N_in, N_out) -> (B, N_out)
            g = sigmoid(g @ w.T + b)
            gs.append(g)

        assert [g.shape for g in gs] == [(B, n) for n in self.sizes], \
            f'Shape mismatch: {[g.shape for g in gs]} vs {[(B, n) for n in self.sizes]}'

        # Now go backward from the final cost applying backpropagation.
        grad_g = self.cost_derivative(gs[-1], y)  # shape initially (B, N^last), then layer by layer.

        grads_w = []
        grads_b = []

        # Loop backwards
        for i in reversed(range(len(self.weights))):
            g = gs[i + 1]          # (B, N^i)
            prev_g = gs[i]         # (B, N^{i-1})

            # derivative of sigmoid(z)
            grad_f = grad_g * (g * (1 - g))          # (B, N^i)
            grad_b = np.mean(grad_f, axis=0)         # (N^i,)
            grad_w = grad_f.T @ prev_g / B           # divide by B for mean

            grads_w.append(grad_w)
            grads_b.append(grad_b)

            # propagate gradient backward to previous layer
            grad_g = grad_f @ self.weights[i]        # (B, N^{i-1})

        grads_w.reverse()
        grads_b.reverse()

        # Now grads_w should have shapes (N^1, N^0), ..., (N^last, N^{last-1}).
        # Now grads_b should have shapes (N^1,) ..., (N^last,).
        for grad_b, b in zip(grads_b, self.biases, strict=True):
            assert grad_b.shape == b.shape, f'Shape mismatch: {grad_b.shape=} but {b.shape=}'
        for grad_w, w in zip(grads_w, self.weights, strict=True):
            assert grad_w.shape == w.shape, f'Shape mismatch: {grad_w.shape=} but {w.shape=}'

        return grads_w, grads_b

    def cost_derivative(self, a: FloatNDArray, y: FloatNDArray) -> FloatNDArray:
        """
        Gradient of loss (MSE) over output activations.

        Args:
        - a: output activations, shape (B, N^last).
        - y: target values (one-hot encoded labels), shape (B, N^last).

        Returns gradients, shape (B, N^last).
        """
        assert a.shape == y.shape, f"Shape mismatch: {a.shape=} but {y.shape=}"
        B, N_last = a.shape
        return (2 / (B * N_last)) * (a - y.astype(np.float64))

    def evaluate(self, x_test_data: FloatNDArray, y_test_data: FloatNDArray) -> np.float64:
        """
        Compute accuracy: the ratio of correct answers for test_data.

        Args:
        - x_test_data: shape (B, N^0).
        - y_test_data: shape (B, N^last).
        """
        predictions = np.argmax(self.feedforward(x_test_data), axis=1)
        targets = np.argmax(y_test_data, axis=1)
        return np.mean(predictions == targets)

    def train(
        self,
        training_data: tuple[FloatNDArray, FloatNDArray],
        test_data: tuple[FloatNDArray, FloatNDArray] | None = None,
        epochs: int = 2,
        mini_batch_size: int = 100,
        learning_rate: float = 1.0
    ) -> np.float64:
        x_train, y_train = training_data
        progress_bar = tqdm(range(epochs), desc="Epoch")
        for epoch in progress_bar:
            for i in range(x_train.shape[0] // mini_batch_size):
                i_begin = i * mini_batch_size
                i_end = (i + 1) * mini_batch_size
                self.learning_step(x_train[i_begin:i_end], y_train[i_begin:i_end], learning_rate)
            if test_data:
                x_test, y_test = test_data
                accuracy = self.evaluate(x_test, y_test)
                progress_bar.set_postfix_str(f"Test accuracy: {accuracy * 100:.2f} %")

        if test_data:
            x_test, y_test = test_data
            return self.evaluate(x_test, y_test)
        else:
            return np.float64(-1)

model_results.evaluate_model(model_name="Baseline", model_constructor=Network, n_trainings=3)
model_results.display_results()
# Out:
# Checking 3 random trainings with with lr = 1.0
# Epoch: 100%|██████████| 10/10 [00:32<00:00,  3.24s/it, Test accuracy: 23.34 %]
# Epoch: 100%|██████████| 10/10 [00:12<00:00,  1.28s/it, Test accuracy: 24.45 %]
# Epoch: 100%|██████████| 10/10 [00:11<00:00,  1.17s/it, Test accuracy: 26.71 %]
# Checking 3 random trainings with with lr = 10.0
# Epoch: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it, Test accuracy: 65.40 %]
# Epoch: 100%|██████████| 10/10 [00:11<00:00,  1.18s/it, Test accuracy: 67.13 %]
# Epoch: 100%|██████████| 10/10 [00:12<00:00,  1.20s/it, Test accuracy: 62.68 %]
# Checking 3 random trainings with with lr = 100.0
# Epoch: 100%|██████████| 10/10 [00:15<00:00,  1.57s/it, Test accuracy: 91.20 %]
# Epoch: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it, Test accuracy: 90.90 %]
# Epoch: 100%|██████████| 10/10 [00:15<00:00,  1.59s/it, Test accuracy: 91.25 %]
# <style type="text/css">
# </style>
# <table id="T_20d55" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_20d55_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_20d55_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_20d55_level0_col2" class="col_heading level0 col2" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_20d55_row0_col0" class="data row0 col0" >Baseline</td>
#       <td id="T_20d55_row0_col1" class="data row0 col1" >1e+02</td>
#       <td id="T_20d55_row0_col2" class="data row0 col2" >91.1% ± 0.2 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_20d55_row1_col0" class="data row1 col0" >Baseline</td>
#       <td id="T_20d55_row1_col1" class="data row1 col1" >1e+01</td>
#       <td id="T_20d55_row1_col2" class="data row1 col2" >65.1% ± 1.8 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_20d55_row2_col0" class="data row2 col0" >Baseline</td>
#       <td id="T_20d55_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_20d55_row2_col2" class="data row2 col2" >24.8% ± 1.4 p.p.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Task 1: softmax & cross-entropy loss
# Use softmax instead of coordinate-wise sigmoid and use negative-log-loss instead of MSE. Test to see if this improves convergence.
#
# Hints:
# * When implementing backprop it's easier to consider these two functions as a single block, skipping the computation of the gradient over the softmax values, and going directly to gradients over logits (last pre-activations).
# * Softmax is only used after the last layer; previous layers (and their grad computations) can be unchanged.
# * Remember to update the forward pass in both places.
# * Loss for a mini-batch is the mean of losses for each dataitem in it, by convention.

# %%
class Task1(Network):
    def __init__(self, sizes: Sequence[int]):
        super().__init__(sizes=sizes)
        self.weights = [
            np.random.randn(n_out, n_in) / np.sqrt(n_in)
            for n_in, n_out in zip(sizes[:-1], sizes[1:], strict=True)
        ]
        self.biases = [
            np.random.randn(n_out) / np.sqrt(n_out) for n_out in sizes[1:]
        ]

    def feedforward(self, x: FloatNDArray) -> FloatNDArray:
        g = x
        for i, (w, b) in enumerate(zip(self.weights, self.biases, strict=True)):
            g = g @ w.T + b
            if i == len(self.weights) - 1:
                g = stable_softmax(g)
            else:
                g = sigmoid(g)
        return g

    def backprop(
        self, x: FloatNDArray, y: FloatNDArray
    ) -> tuple[list[FloatNDArray], list[FloatNDArray]]:
        B, N0 = x.shape
        assert N0 == self.sizes[0]

        # Forward pass.
        # Activations (including input) of shapes (B, N^0), (B, N^1), ..., (B, N^last).
        gs: list[FloatNDArray] = [x]
        g = x
        for i, (w, b) in enumerate(zip(self.weights, self.biases, strict=True)):
            g = g @ w.T + b
            if i == len(self.weights) - 1:
                g = stable_softmax(g)
            else:
                g = sigmoid(g)
            gs.append(g)

        grads_w = []  # Shapes (N^last, N^{last-1}), ..., (N^1, N^0).
        grads_b = []  # Shapes (N^last,), ..., (N^1,).

        grad_f = gs[-1] - y
        grad_g = None

        for i in range(len(self.weights)-1, -1, -1):
            g = gs[i + 1]  # (B, N^i)
            prev_g = gs[i]  # (B, N^{i-1})

            if i == len(self.weights) - 1:
                # softmax
                pass
            else:
                # sigmoid
                grad_f = grad_g * g * (1 - g) # type: ignore

            grad_b = np.mean(grad_f, axis=0)
            grad_w = grad_f.T @ prev_g / B

            grads_w.append(grad_w)
            grads_b.append(grad_b)

            grad_g = grad_f @ self.weights[i]

        grads_w.reverse()  # Now shapes (N^1, N^0), ..., (N^last, N^{last-1}).
        grads_b.reverse()  # Now shapes (N^1,) ..., (N^last,).

        for grad_b, b in zip(grads_b, self.biases, strict=True):
            assert grad_b.shape == b.shape, f"Shape mismatch: {grad_b.shape=} but {b.shape=}"
        for grad_w, w in zip(grads_w, self.weights, strict=True):
            assert grad_w.shape == w.shape, f"Shape mismatch: {grad_w.shape=} but {w.shape=}"

        return grads_w, grads_b


model_results.evaluate_model(model_name="SoftMax", model_constructor=Task1, n_trainings=3,
                             learning_rates=[1.0, 3.0, 10.0])
model_results.display_results()
# Out:
# Checking 3 random trainings with with lr = 1.0
# Epoch: 100%|██████████| 10/10 [00:11<00:00,  1.19s/it, Test accuracy: 96.54 %]
# Epoch: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it, Test accuracy: 96.27 %]
# Epoch: 100%|██████████| 10/10 [00:16<00:00,  1.69s/it, Test accuracy: 96.33 %]
# Checking 3 random trainings with with lr = 3.0
# Epoch: 100%|██████████| 10/10 [00:14<00:00,  1.42s/it, Test accuracy: 96.08 %]
# Epoch: 100%|██████████| 10/10 [00:11<00:00,  1.18s/it, Test accuracy: 95.90 %]
# Epoch: 100%|██████████| 10/10 [00:17<00:00,  1.80s/it, Test accuracy: 95.50 %]
# Checking 3 random trainings with with lr = 10.0
# Epoch: 100%|██████████| 10/10 [00:11<00:00,  1.18s/it, Test accuracy: 91.00 %]
# Epoch: 100%|██████████| 10/10 [00:11<00:00,  1.18s/it, Test accuracy: 93.08 %]
# Epoch: 100%|██████████| 10/10 [00:12<00:00,  1.24s/it, Test accuracy: 89.32 %]
# <style type="text/css">
# </style>
# <table id="T_727e6" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_727e6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_727e6_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_727e6_level0_col2" class="col_heading level0 col2" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_727e6_row0_col0" class="data row0 col0" >SoftMax</td>
#       <td id="T_727e6_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_727e6_row0_col2" class="data row0 col2" >96.4% ± 0.1 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_727e6_row1_col0" class="data row1 col0" >SoftMax</td>
#       <td id="T_727e6_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_727e6_row1_col2" class="data row1 col2" >95.8% ± 0.2 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_727e6_row2_col0" class="data row2 col0" >SoftMax</td>
#       <td id="T_727e6_row2_col1" class="data row2 col1" >1e+01</td>
#       <td id="T_727e6_row2_col2" class="data row2 col2" >91.1% ± 1.5 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_727e6_row3_col0" class="data row3 col0" >Baseline</td>
#       <td id="T_727e6_row3_col1" class="data row3 col1" >1e+02</td>
#       <td id="T_727e6_row3_col2" class="data row3 col2" >91.1% ± 0.2 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_727e6_row4_col0" class="data row4 col0" >Baseline</td>
#       <td id="T_727e6_row4_col1" class="data row4 col1" >1e+01</td>
#       <td id="T_727e6_row4_col2" class="data row4 col2" >65.1% ± 1.8 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_727e6_row5_col0" class="data row5 col0" >Baseline</td>
#       <td id="T_727e6_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_727e6_row5_col2" class="data row5 col2" >24.8% ± 1.4 p.p.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Task 2: L2-regularization and momentum
# Implement L2-regularization and add momentum to the SGD algorithm. Play with different amounts of regularization and momentum. See if this improves accuracy/convergence.
# A few notes:
# * do not regularize the biases
# * you can see an example pseudocode here [pytorch.org/docs/stable/generated/torch.optim.SGD.html](https://pytorch.org/docs/stable/generated/torch.optim.SGD.html)

# %%
class Task2(Network):
    def __init__(
        self, sizes: Sequence[int], l2_factor: float = 1e-5, momentum: float = 0.2
    ):
        super().__init__(sizes=sizes)
        self.l2_factor = l2_factor
        self.momentum = momentum
        self.sizes = sizes

    def learning_step(self, x_mini_batch: FloatNDArray, y_mini_batch: FloatNDArray, learning_rate: float) -> None:
        """
        Update parameters with one mini-batch step of backprop and gradient descent (with momentum and L2-regularization).

        Args:
        - x_mini_batch: shape (B, N^0) where B is mini_batch_size.
        - y_mini_batch: shape (B, N^last).
        - learning_rate.
        """
        grads_w, grads_b = self.backprop(x_mini_batch, y_mini_batch)

        # initialize momentum buffers if not already
        if not hasattr(self, "w_velocity"):
            self.w_velocity = [np.zeros_like(w) for w in self.weights]
            self.b_velocity = [np.zeros_like(b) for b in self.biases]

        # parameter update
        for i in range(len(self.weights)):
            self.w_velocity[i] = (
                self.momentum * self.w_velocity[i]
                + grads_w[i]
                + self.l2_factor * self.weights[i]
            )
            self.b_velocity[i] = (
                self.momentum * self.b_velocity[i]
                + grads_b[i]
                + self.l2_factor * self.biases[i]
            )

            self.weights[i] -= learning_rate * self.w_velocity[i]
            self.biases[i]  -= learning_rate * self.b_velocity[i]

model_results.evaluate_model(
    model_name=f"L2&Momentum",
    model_constructor=Task2,
    learning_rates=[100.0],
    n_trainings=1,
    l2_factor=1e-7,
    momentum=0.02
)
model_results.display_results()
# Out:
# Checking 1 random trainings with with lr = 100.0
# Epoch: 100%|██████████| 10/10 [00:14<00:00,  1.44s/it, Test accuracy: 90.94 %]
# <style type="text/css">
# </style>
# <table id="T_f7cee" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_f7cee_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f7cee_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_f7cee_level0_col2" class="col_heading level0 col2" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f7cee_row0_col0" class="data row0 col0" >SoftMax</td>
#       <td id="T_f7cee_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_f7cee_row0_col2" class="data row0 col2" >96.4% ± 0.1 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_f7cee_row1_col0" class="data row1 col0" >SoftMax</td>
#       <td id="T_f7cee_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_f7cee_row1_col2" class="data row1 col2" >95.8% ± 0.2 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_f7cee_row2_col0" class="data row2 col0" >SoftMax</td>
#       <td id="T_f7cee_row2_col1" class="data row2 col1" >1e+01</td>
#       <td id="T_f7cee_row2_col2" class="data row2 col2" >91.1% ± 1.5 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_f7cee_row3_col0" class="data row3 col0" >Baseline</td>
#       <td id="T_f7cee_row3_col1" class="data row3 col1" >1e+02</td>
#       <td id="T_f7cee_row3_col2" class="data row3 col2" >91.1% ± 0.2 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_f7cee_row4_col0" class="data row4 col0" >L2&Momentum(l2_factor=1e-07,momentum=0.02)</td>
#       <td id="T_f7cee_row4_col1" class="data row4 col1" >1e+02</td>
#       <td id="T_f7cee_row4_col2" class="data row4 col2" >90.9% ± 0.0 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_f7cee_row5_col0" class="data row5 col0" >Baseline</td>
#       <td id="T_f7cee_row5_col1" class="data row5 col1" >1e+01</td>
#       <td id="T_f7cee_row5_col2" class="data row5 col2" >65.1% ± 1.8 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_f7cee_row6_col0" class="data row6 col0" >Baseline</td>
#       <td id="T_f7cee_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_f7cee_row6_col2" class="data row6 col2" >24.8% ± 1.4 p.p.</td>
#     </tr>
#   </tbody>
# </table>

# %%
class Task1And2(Task2, Task1):
    # A somewhat hacky but short way to mix Task1 and Task2.
    # You could also just replace the superclass of Task2 to be Task1.
	def __init__(
		self, sizes: Sequence[int], l2_factor: float = 1e-5, momentum: float = 0.2
	):
		Task1.__init__(self, sizes=sizes)
		self.l2_factor = l2_factor
		self.momentum = momentum
		self.sizes = sizes

model_results.evaluate_model(
    model_name=f"Softmax&L2&Momentum",
    model_constructor=Task1And2,
    learning_rates=[2.0],
    n_trainings=1,
    l2_factor=1e-4,
    momentum=0.2
)
model_results.display_results()
# Out:
# Checking 1 random trainings with with lr = 2.0
# Epoch: 100%|██████████| 10/10 [00:12<00:00,  1.24s/it, Test accuracy: 96.22 %]
# <style type="text/css">
# </style>
# <table id="T_cc03d" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_cc03d_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_cc03d_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_cc03d_level0_col2" class="col_heading level0 col2" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cc03d_row0_col0" class="data row0 col0" >SoftMax</td>
#       <td id="T_cc03d_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_cc03d_row0_col2" class="data row0 col2" >96.4% ± 0.1 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_cc03d_row1_col0" class="data row1 col0" >Softmax&L2&Momentum(l2_factor=0.0001,momentum=0.2)</td>
#       <td id="T_cc03d_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_cc03d_row1_col2" class="data row1 col2" >96.2% ± 0.0 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_cc03d_row2_col0" class="data row2 col0" >SoftMax</td>
#       <td id="T_cc03d_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_cc03d_row2_col2" class="data row2 col2" >95.8% ± 0.2 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_cc03d_row3_col0" class="data row3 col0" >SoftMax</td>
#       <td id="T_cc03d_row3_col1" class="data row3 col1" >1e+01</td>
#       <td id="T_cc03d_row3_col2" class="data row3 col2" >91.1% ± 1.5 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_cc03d_row4_col0" class="data row4 col0" >Baseline</td>
#       <td id="T_cc03d_row4_col1" class="data row4 col1" >1e+02</td>
#       <td id="T_cc03d_row4_col2" class="data row4 col2" >91.1% ± 0.2 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_cc03d_row5_col0" class="data row5 col0" >L2&Momentum(l2_factor=1e-07,momentum=0.02)</td>
#       <td id="T_cc03d_row5_col1" class="data row5 col1" >1e+02</td>
#       <td id="T_cc03d_row5_col2" class="data row5 col2" >90.9% ± 0.0 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_cc03d_row6_col0" class="data row6 col0" >Baseline</td>
#       <td id="T_cc03d_row6_col1" class="data row6 col1" >1e+01</td>
#       <td id="T_cc03d_row6_col2" class="data row6 col2" >65.1% ± 1.8 p.p.</td>
#     </tr>
#     <tr>
#       <td id="T_cc03d_row7_col0" class="data row7 col0" >Baseline</td>
#       <td id="T_cc03d_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_cc03d_row7_col2" class="data row7 col2" >24.8% ± 1.4 p.p.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Task 3 (optional)
# Implement more variations of SGD:
# * AdamW (probably the most popular choice) or Adagrad,
# * dropout
# * some simple data augmentations (e.g. tiny rotations/shifts etc.).
#
# Again, test to see how these changes improve accuracy/convergence.
#
# Quick reminders:
# * for AdamW, check the official [PyTorch documentation](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html)'s pseudocode or the original paper: [Decoupled Weight Decay Regularization](https://arxiv.org/abs/1711.05101).
# * for AdaGrad, check the Appendix of this notebook.
# * for dropout: during training only, zero-out each activation in the considered layer with probability $p$, and multiplying other activations by $\frac{1}{1-p}$.

# %%
class Task3(Network):
    def __init__(self, sizes: Sequence[int], epsilon: float = 1e-8,
                 weight_decay: float = 0.02, alpha: float = 0.001,
                 beta_1: float = 0.9, beta_2: float = 0.999):
        super().__init__(sizes=sizes)
        self.epsilon = epsilon
        self.weight_decay = weight_decay
        self.alpha = alpha
        self.beta_1 = beta_1
        self.beta_2 = beta_2
        self.time_step = 0

        self.weights = [np.random.randn(n_out, n_in) / np.sqrt(n_in) for n_in, n_out in zip(sizes[:-1], sizes[1:], strict=True)]
        self.biases = [np.random.randn(n_out) / np.sqrt(n_out) for n_out in sizes[1:]]

        self.m_weights = [np.zeros_like(w) for w in self.weights]
        self.m_bias = [np.zeros_like(w) for w in self.biases]
        self.v_weights = [np.zeros_like(w) for w in self.weights]
        self.v_bias = [np.zeros_like(w) for w in self.biases]

    # learning step using AdamW
    def learning_step(self, x_mini_batch: FloatNDArray, y_mini_batch: FloatNDArray, learning_rate: float) -> None:
        grads_w, grads_b = self.backprop(x_mini_batch, y_mini_batch)
        self.time_step += 1

        def recalc(params, grad_t, m_tminus1, v_tminus1):
            m_t = self.beta_1 * m_tminus1 + (1 - self.beta_1) * grad_t
            v_t = self.beta_2 * v_tminus1 + (1 - self.beta_2) * grad_t ** 2
            m_hat_t = m_t / (1 - self.beta_1 ** self.time_step)
            v_hat_t = v_t / (1 - self.beta_2 ** self.time_step)
            w_params = params - learning_rate * (self.alpha * m_hat_t / (np.sqrt(v_hat_t) + self.epsilon) + self.weight_decay * params)
            return w_params, m_t, v_t

        for t in range(len(self.weights)):
            weights_params, weights_m_t, weights_v_t = recalc(self.weights[t], grads_w[t], self.m_weights[t], self.v_weights[t])
            self.weights[t] = weights_params
            self.m_weights[t] = weights_m_t
            self.v_weights[t] = weights_v_t

            biases_params, biases_m_t, biases_v_t = recalc(self.biases[t], grads_b[t], self.m_bias[t], self.v_bias[t])
            self.biases[t] = biases_params
            self.m_bias[t] = biases_m_t
            self.v_bias[t] = biases_v_t

        # for i, (gw, gb) in enumerate(zip(grads_w, grads_b)):
        #     w_norm = np.linalg.norm(gw)
        #     b_norm = np.linalg.norm(gb)
        #     print(f"Layer {i}: ||grad_w||={w_norm:.2e}, ||grad_b||={b_norm:.2e}")

model_results.evaluate_model(
    model_name=f"AdamWNetwork",
    model_constructor=Task3,
    learning_rates=[0.001],
    n_trainings=1,
    # layers=(784, 125, 30, 10)
  )
# Out:
# Checking 1 random trainings with with lr = 0.001
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Layer 0: ||grad_w||=8.39e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=8.33e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.25e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.52e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.92e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.16e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.25e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.19e-04, ||grad_b||=1.43e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=8.69e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.47e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.54e-04, ||grad_b||=1.42e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.95e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=1.08e-03, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=1.04e-03, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.34e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.06e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.69e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.35e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.37e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.27e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=9.52e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.67e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.86e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.24e-04, ||grad_b||=1.42e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.52e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.90e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.66e-04, ||grad_b||=1.42e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.03e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.82e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.33e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.31e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.43e-04
# Layer 0: ||grad_w||=8.04e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.17e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.27e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.90e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.44e-04
# Layer 0: ||grad_w||=8.04e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.97e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.43e-04
# Layer 0: ||grad_w||=8.25e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.44e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.56e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.05e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.52e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.45e-04
# Layer 0: ||grad_w||=7.96e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.18e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.75e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=9.71e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.68e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=9.02e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=8.01e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.84e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.81e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=9.14e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.30e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.45e-04
# Layer 0: ||grad_w||=9.49e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.99e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.82e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.61e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.53e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.27e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=1.00e-03, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=1.01e-03, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.72e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=9.54e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.51e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.48e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=8.15e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.21e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.03e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=9.05e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=7.97e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.88e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.37e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=6.93e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.83e-04, ||grad_b||=1.42e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.96e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.18e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=8.38e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=9.03e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.24e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.07e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=7.86e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.37e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=9.05e-04, ||grad_b||=1.42e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=9.56e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.98e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=9.89e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.83e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=8.34e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.32e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.48e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.59e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=7.54e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.78e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.41e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.43e-04
# Layer 0: ||grad_w||=8.49e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.54e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.79e-03, ||grad_b||=6.48e-04
# Layer 0: ||grad_w||=8.73e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.40e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.19e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.78e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=7.84e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=1.16e-03, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.46e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.46e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=9.07e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=7.80e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.29e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=9.34e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=9.21e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.25e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=8.65e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.32e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.83e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.50e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.21e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.43e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.64e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.64e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.81e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=9.31e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.88e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=9.15e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.68e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.45e-04
# Layer 0: ||grad_w||=9.09e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.94e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.14e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=7.71e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.66e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.65e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=1.03e-03, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=9.22e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=8.82e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=8.85e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.51e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=9.75e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=7.84e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=7.56e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.03e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.00e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=9.39e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.40e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.28e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.43e-04
# Layer 0: ||grad_w||=9.03e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.21e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.38e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.49e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.36e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.22e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.21e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.19e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.52e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.07e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=7.76e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.58e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.07e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.09e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.21e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=7.94e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.65e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.23e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.36e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.96e-04, ||grad_b||=1.42e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.57e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.53e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.15e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.98e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.15e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=7.74e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.20e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.15e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.01e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.43e-04
# Layer 0: ||grad_w||=8.61e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.41e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.44e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.56e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.55e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=7.56e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.54e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=7.91e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.75e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=8.83e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.52e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.53e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.12e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.40e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.05e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.21e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.07e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=7.71e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.84e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.35e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=9.49e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.41e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.76e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.25e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.44e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.83e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.20e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.79e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.53e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.04e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.28e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.71e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.84e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.17e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.44e-04
# Layer 0: ||grad_w||=8.54e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.55e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.97e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=7.72e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.17e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.22e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.45e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.84e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.46e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=7.76e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.23e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=1.01e-03, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.74e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.45e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.14e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.38e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.27e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.19e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.41e-04
# Layer 0: ||grad_w||=8.75e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.46e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.65e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.26e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.27e-04
# Layer 0: ||grad_w||=8.98e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.99e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.92e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.89e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.94e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.65e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.06e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.70e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.93e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.57e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.32e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.27e-04
# Layer 0: ||grad_w||=9.04e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.93e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.36e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.00e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.15e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.24e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.03e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.63e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=7.45e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.24e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.26e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.49e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=1.04e-03, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.78e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.66e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.49e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.40e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.21e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.71e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.77e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.56e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.31e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.98e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.39e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.26e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.18e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.34e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.81e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.15e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.46e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.18e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.89e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.35e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.43e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.65e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.33e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.29e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.64e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.74e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.12e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=9.28e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.34e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=9.25e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.70e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=9.16e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.48e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.87e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.55e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.88e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.30e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.00e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=8.40e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.87e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=9.47e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.02e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.94e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.31e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=7.14e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.04e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.09e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=8.70e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.95e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.30e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=6.79e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.05e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.76e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.27e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.12e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.63e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.76e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.76e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.94e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=7.26e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.31e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.68e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.41e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.00e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=9.16e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.64e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.69e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.31e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.68e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=7.95e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.72e-03, ||grad_b||=6.26e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.91e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.02e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.66e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.41e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.55e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.77e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.00e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.84e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.27e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.55e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=9.10e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.71e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.10e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.08e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.30e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.86e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.82e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.42e-04
# Layer 0: ||grad_w||=8.75e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.25e-04
# Layer 0: ||grad_w||=8.74e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.46e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.44e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=8.72e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.92e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=9.22e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.39e-04
# Layer 0: ||grad_w||=7.97e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.72e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=8.73e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.92e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.27e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.38e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.58e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.81e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.08e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=6.86e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.14e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=9.53e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.63e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.18e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=9.11e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=1.03e-03, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=1.04e-03, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=9.07e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.52e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=8.93e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=1.00e-03, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.43e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.80e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.38e-04, ||grad_b||=1.41e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.66e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.26e-04
# Layer 0: ||grad_w||=7.44e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.86e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.78e-03, ||grad_b||=6.43e-04
# Layer 0: ||grad_w||=8.55e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=8.14e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.59e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.98e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.31e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.89e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=7.91e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.26e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.72e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=8.62e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.26e-04
# Layer 0: ||grad_w||=8.31e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.70e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=7.91e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.35e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.27e-04
# Layer 0: ||grad_w||=9.49e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=9.21e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=9.00e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=9.01e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.72e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=8.97e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=9.00e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=6.96e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.36e-04
# Layer 0: ||grad_w||=7.51e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.20e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.57e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.67e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.08e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.77e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=9.30e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.94e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.08e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.75e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.02e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.86e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.43e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.23e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.27e-04
# Layer 0: ||grad_w||=8.33e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.44e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.49e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=6.73e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.83e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=9.09e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=9.15e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=9.02e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.98e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.19e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.26e-04
# Layer 0: ||grad_w||=7.84e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.42e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.27e-04
# Layer 0: ||grad_w||=9.54e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=8.84e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.78e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.92e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.03e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.44e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.67e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.47e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.25e-04
# Layer 0: ||grad_w||=8.38e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.37e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.76e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.45e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.61e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.96e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.80e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.18e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.20e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=7.94e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.37e-04
# Layer 0: ||grad_w||=8.37e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.27e-04
# Layer 0: ||grad_w||=7.79e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=7.77e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.56e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.72e-03, ||grad_b||=6.25e-04
# Layer 0: ||grad_w||=8.51e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.40e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=8.16e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.05e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=7.35e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.82e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.27e-04
# Layer 0: ||grad_w||=8.25e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.19e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.77e-03, ||grad_b||=6.40e-04
# Layer 0: ||grad_w||=8.28e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=7.09e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=7.00e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=7.50e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=8.09e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.35e-04
# Layer 0: ||grad_w||=8.27e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.28e-04
# Layer 0: ||grad_w||=7.98e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=8.20e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.58e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.32e-04
# Layer 0: ||grad_w||=9.26e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.69e-04, ||grad_b||=1.36e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.33e-04
# Layer 0: ||grad_w||=8.36e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.76e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.36e-04, ||grad_b||=1.40e-04
# Layer 1: ||grad_w||=1.73e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.36e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=7.31e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.72e-03, ||grad_b||=6.23e-04
# Layer 0: ||grad_w||=7.91e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=8.62e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# Layer 0: ||grad_w||=9.04e-04, ||grad_b||=1.39e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.30e-04
# Layer 0: ||grad_w||=9.46e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.75e-03, ||grad_b||=6.34e-04
# Layer 0: ||grad_w||=8.58e-04, ||grad_b||=1.38e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.29e-04
# Layer 0: ||grad_w||=9.16e-04, ||grad_b||=1.37e-04
# Layer 1: ||grad_w||=1.74e-03, ||grad_b||=6.31e-04
# ...
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.55e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=8.41e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=9.78e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=1.04e-03, ||grad_b||=1.21e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.91e-04
# Layer 0: ||grad_w||=7.31e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=7.80e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=7.96e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=8.99e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=7.00e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.05e-04
# Layer 0: ||grad_w||=7.46e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.06e-04
# Layer 0: ||grad_w||=7.41e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=7.32e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.57e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.04e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=7.25e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.33e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.27e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.69e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.50e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=6.73e-04, ||grad_b||=1.27e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.07e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=9.44e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=9.08e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.42e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.17e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=6.86e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=7.40e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.42e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=8.19e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=8.37e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.71e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.86e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.30e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.65e-03, ||grad_b||=5.94e-04
# Layer 0: ||grad_w||=7.56e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=7.85e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.68e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.13e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.79e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=7.41e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=7.42e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.08e-04
# Layer 0: ||grad_w||=7.15e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.30e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.33e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.09e-04, ||grad_b||=1.27e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.10e-04
# Layer 0: ||grad_w||=7.14e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.92e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=7.32e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.24e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=7.51e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.58e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.18e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.53e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.70e-03, ||grad_b||=6.08e-04
# Layer 0: ||grad_w||=7.11e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.06e-04
# Layer 0: ||grad_w||=7.27e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=7.76e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=8.54e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=7.69e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.13e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=7.80e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.75e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=8.04e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=8.19e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.06e-04
# Layer 0: ||grad_w||=8.35e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=7.95e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.80e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.63e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.55e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=8.14e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=8.76e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=8.83e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.65e-03, ||grad_b||=5.92e-04
# Layer 0: ||grad_w||=8.56e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=8.40e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.95e-04
# Layer 0: ||grad_w||=7.55e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.57e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.06e-04
# Layer 0: ||grad_w||=7.25e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=6.47e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=7.13e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.98e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.09e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.04e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=6.56e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=6.20e-04, ||grad_b||=1.27e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.02e-04, ||grad_b||=1.27e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=7.10e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=7.27e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.07e-04
# Layer 0: ||grad_w||=7.44e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.96e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=8.13e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.94e-04
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.02e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=7.41e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=8.03e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=8.38e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.95e-04
# Layer 0: ||grad_w||=8.76e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=8.68e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.94e-04
# Layer 0: ||grad_w||=7.84e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=7.39e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.38e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=7.51e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=6.78e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.05e-04
# Layer 0: ||grad_w||=6.72e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.77e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=7.45e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.06e-04
# Layer 0: ||grad_w||=7.54e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.65e-03, ||grad_b||=5.95e-04
# Layer 0: ||grad_w||=7.61e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.71e-03, ||grad_b||=6.12e-04
# Layer 0: ||grad_w||=7.71e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# Layer 0: ||grad_w||=7.43e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.97e-04
# Layer 0: ||grad_w||=7.28e-04, ||grad_b||=1.26e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.78e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=6.99e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=1.00e-03, ||grad_b||=1.20e-04
# Layer 1: ||grad_w||=1.65e-03, ||grad_b||=5.89e-04
# Layer 0: ||grad_w||=8.29e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.95e-04
# Layer 0: ||grad_w||=8.32e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=8.01e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.65e-03, ||grad_b||=5.93e-04
# Layer 0: ||grad_w||=6.97e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=7.38e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=8.27e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=8.09e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.65e-03, ||grad_b||=5.93e-04
# Layer 0: ||grad_w||=8.12e-04, ||grad_b||=1.22e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.68e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=6.00e-04
# Layer 0: ||grad_w||=7.38e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.82e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.65e-03, ||grad_b||=5.93e-04
# Layer 0: ||grad_w||=7.55e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=7.29e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.49e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=7.65e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.03e-04
# Layer 0: ||grad_w||=7.67e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=7.82e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.06e-04
# Layer 0: ||grad_w||=8.22e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.02e-04
# Layer 0: ||grad_w||=7.86e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.68e-03, ||grad_b||=6.04e-04
# Layer 0: ||grad_w||=8.06e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=5.99e-04
# Layer 0: ||grad_w||=7.67e-04, ||grad_b||=1.24e-04
# Layer 1: ||grad_w||=1.69e-03, ||grad_b||=6.08e-04
# Epoch:  40%|████      | 4/10 [00:09<00:13,  2.31s/it, Test accuracy: 7.39 %]
# Layer 0: ||grad_w||=7.99e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.95e-04
# Layer 0: ||grad_w||=7.86e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.96e-04
# Layer 0: ||grad_w||=8.07e-04, ||grad_b||=1.25e-04
# Layer 1: ||grad_w||=1.66e-03, ||grad_b||=5.98e-04
# Layer 0: ||grad_w||=6.84e-04, ||grad_b||=1.23e-04
# Layer 1: ||grad_w||=1.67e-03, ||grad_b||=6.01e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2109617742.py in <cell line: 0>()
#      48             print(f"Layer {i}: ||grad_w||={w_norm:.2e}, ||grad_b||={b_norm:.2e}")
#      49
# ---> 50 model_results.evaluate_model(
#      51     model_name=f"AdamWNetwork",
#      52     model_constructor=Task3,
#
# /tmp/ipython-input-3806505274.py in evaluate_model(self, model_name, model_constructor, layers, learning_rates, n_trainings, **kwargs)
#      65             for i in range(n_trainings):
#      66                 network = model_constructor(layers, **kwargs)
# ---> 67                 accuracy = network.train(
#      68                     (x_train, y_train),
#      69                     epochs=10,
#
# /tmp/ipython-input-1558297110.py in train(self, training_data, test_data, epochs, mini_batch_size, learning_rate)
#     159                 i_begin = i * mini_batch_size
#     160                 i_end = (i + 1) * mini_batch_size
# --> 161                 self.learning_step(x_train[i_begin:i_end], y_train[i_begin:i_end], learning_rate)
#     162             if test_data:
#     163                 x_test, y_test = test_data
#
# /tmp/ipython-input-2109617742.py in learning_step(self, x_mini_batch, y_mini_batch, learning_rate)
#      21     # learning step using AdamW
#      22     def learning_step(self, x_mini_batch: FloatNDArray, y_mini_batch: FloatNDArray, learning_rate: float) -> None:
# ---> 23         grads_w, grads_b = self.backprop(x_mini_batch, y_mini_batch)
#      24         self.time_step += 1
#      25
#
# /tmp/ipython-input-1558297110.py in backprop(self, x, y)
#      79         for w, b in zip(self.weights, self.biases, strict=True):
#      80             # (B, N_in) @ (N_in, N_out) -> (B, N_out)
# ---> 81             g = sigmoid(g @ w.T + b)
#      82             gs.append(g)
#      83
#
# /tmp/ipython-input-3898644277.py in sigmoid(z)
# ----> 1 def sigmoid(z: FloatNDArray) -> FloatNDArray:
#       2     return 1.0 / (1.0 + np.exp(-z))
#       3
#       4
#       5 def sigmoid_prime(z: FloatNDArray) -> FloatNDArray:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Task 4
# Try adding extra layers to the network. Again, test how the changes you introduced affect accuracy/convergence and what learning rates work.
#
# As a start, you can try this slightly larger architecture: [784,100,30,10]

# %%
# Hyperparameter optimization with Optuna
# !pip install optuna
import optuna

def objective(trial) -> float:
	l2_factor = trial.suggest_float("l2_factor", 1e-6, 1e-2, log=True)
	momentum = trial.suggest_float("momentum", 0.01, 0.5, log=True)
	learning_rate = trial.suggest_float("learning_rate", 0.1, 100.0, log=True)
	sizes = trial.suggest_categorical("sizes", [(784, 30, 10), (784, 128, 32, 10), (784, 100, 10)])

	model = Task1And2(sizes=sizes, l2_factor=l2_factor, momentum=momentum)

	accuracy = model.train(
		(x_train, y_train),
		epochs=10,
		mini_batch_size=100,
		learning_rate=learning_rate,
		test_data=(x_test, y_test),
	)

	return float(accuracy)

study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=20)
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 6.6 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.5.0
# [I 2025-11-04 11:44:00,051] A new study created in memory with name: no-name-a52d9a1a-a1ad-467e-b43f-0f1a8e2be4aa
# /usr/local/lib/python3.12/dist-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (784, 30, 10) which is of type tuple.
#   warnings.warn(message)
# /usr/local/lib/python3.12/dist-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (784, 128, 32, 10) which is of type tuple.
#   warnings.warn(message)
# /usr/local/lib/python3.12/dist-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (784, 100, 10) which is of type tuple.
#   warnings.warn(message)
# Epoch: 100%|██████████| 10/10 [00:12<00:00,  1.25s/it, Test accuracy: 86.49 %]
# [I 2025-11-04 11:44:12,591] Trial 0 finished with value: 0.8649 and parameters: {'l2_factor': 0.00028681127009567926, 'momentum': 0.01848896023660593, 'learning_rate': 11.699570238267633, 'sizes': (784, 30, 10)}. Best is trial 0 with value: 0.8649.
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]/tmp/ipython-input-3898644277.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-z))
# Epoch: 100%|██████████| 10/10 [00:35<00:00,  3.56s/it, Test accuracy: 9.58 %]
# [I 2025-11-04 11:44:48,324] Trial 1 finished with value: 0.0958 and parameters: {'l2_factor': 0.00010982304007237553, 'momentum': 0.04687733175187862, 'learning_rate': 59.07212802751726, 'sizes': (784, 128, 32, 10)}. Best is trial 0 with value: 0.8649.
# Epoch: 100%|██████████| 10/10 [00:33<00:00,  3.37s/it, Test accuracy: 97.21 %]
# [I 2025-11-04 11:45:22,172] Trial 2 finished with value: 0.9721 and parameters: {'l2_factor': 1.2411581111153736e-06, 'momentum': 0.153243561256128, 'learning_rate': 0.8363265826973046, 'sizes': (784, 128, 32, 10)}. Best is trial 2 with value: 0.9721.
# Epoch:  30%|███       | 3/10 [00:05<00:13,  1.90s/it, Test accuracy: 93.09 %]
# [W 2025-11-04 11:45:27,870] Trial 3 failed with parameters: {'l2_factor': 1.0063401765978816e-05, 'momentum': 0.024646642562349334, 'learning_rate': 6.07435218731106, 'sizes': (784, 30, 10)} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipython-input-3315553966.py", line 13, in objective
#     accuracy = model.train(
#                ^^^^^^^^^^^^
#   File "/tmp/ipython-input-1558297110.py", line 161, in train
#     self.learning_step(x_train[i_begin:i_end], y_train[i_begin:i_end], learning_rate)
#   File "/tmp/ipython-input-1111995069.py", line 19, in learning_step
#     grads_w, grads_b = self.backprop(x_mini_batch, y_mini_batch)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-1462822784.py", line 37, in backprop
#     g = sigmoid(g)
#         ^^^^^^^^^^
#   File "/tmp/ipython-input-3898644277.py", line 1, in sigmoid
#     def sigmoid(z: FloatNDArray) -> FloatNDArray:
#
# KeyboardInterrupt
# [W 2025-11-04 11:45:27,872] Trial 3 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3315553966.py in <cell line: 0>()
#      22
#      23 study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner())
# ---> 24 study.optimize(objective, n_trials=20)
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     488                 If nested invocation of this method occurs.
#     489         """
# --> 490         _optimize(
#     491             study=self,
#     492             func=func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61     try:
#      62         if n_jobs == 1:
# ---> 63             _optimize_sequential(
#      64                 study,
#      65                 func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158
#     159         try:
# --> 160             frozen_trial_id = _run_trial(study, func, catch)
#     161         finally:
#     162             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     256         and not isinstance(func_err, catch)
#     257     ):
# --> 258         raise func_err
#     259     return trial._trial_id
#     260
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     199     with get_heartbeat_thread(trial._trial_id, study._storage):
#     200         try:
# --> 201             value_or_values = func(trial)
#     202         except exceptions.TrialPruned as e:
#     203             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipython-input-3315553966.py in objective(trial)
#      11         model = Task1And2(sizes=sizes, l2_factor=l2_factor, momentum=momentum)
#      12
# ---> 13 	accuracy = model.train(
#      14                 (x_train, y_train),
#      15                 epochs=10,
#
# /tmp/ipython-input-1558297110.py in train(self, training_data, test_data, epochs, mini_batch_size, learning_rate)
#     159                 i_begin = i * mini_batch_size
#     160                 i_end = (i + 1) * mini_batch_size
# --> 161                 self.learning_step(x_train[i_begin:i_end], y_train[i_begin:i_end], learning_rate)
#     162             if test_data:
#     163                 x_test, y_test = test_data
#
# /tmp/ipython-input-1111995069.py in learning_step(self, x_mini_batch, y_mini_batch, learning_rate)
#      17         - learning_rate.
#      18         """
# ---> 19         grads_w, grads_b = self.backprop(x_mini_batch, y_mini_batch)
#      20
#      21         # initialize momentum buffers if not already
#
# /tmp/ipython-input-1462822784.py in backprop(self, x, y)
#      35                 g = stable_softmax(g)
#      36             else:
# ---> 37                 g = sigmoid(g)
#      38             gs.append(g)
#      39
#
# /tmp/ipython-input-3898644277.py in sigmoid(z)
# ----> 1 def sigmoid(z: FloatNDArray) -> FloatNDArray:
#       2     return 1.0 / (1.0 + np.exp(-z))
#       3
#       4
#       5 def sigmoid_prime(z: FloatNDArray) -> FloatNDArray:
#
# KeyboardInterrupt:

# %%
print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
	print(f"    {key}: {value}")

# %%
import optuna.visualization as vis

fig1 = vis.plot_optimization_history(study)
fig2 = vis.plot_param_importances(study)
fig3 = vis.plot_slice(study)

fig1.show()
fig2.show()
fig3.show()

# %% [markdown]
# # Appendix

# %% [markdown]
# ## Adagrad (simplified version)
#
# Let $p_1, \ldots, p_n$ be all parameters in our model (weights and biases).
# For parameter $p_i$ we maintain a variable $G_i$ (can be set to $0$ initially).
# Let $\mathcal{L}$ be our loss without L2.
# We update $G_i$ and $p_i$ each training step as follows:
# $$
# G_i = G_i +  \left(\frac{\partial \mathcal{L}}{\partial p_i}\right)^2\\
# p_i = p_i - \frac{\eta}{\sqrt{\left(G_i + \epsilon\right)}}\frac{\partial \mathcal{L}}{\partial p_i}
# $$

# %%
class AdagradNetwork(Network):
    def __init__(self, sizes: Sequence[int], epsilon: float = 1e-8):
        super().__init__(sizes=sizes)
        self.epsilon = epsilon

        self.weights = [np.random.randn(n_out, n_in) / np.sqrt(n_in) for n_in, n_out in zip(sizes[:-1], sizes[1:], strict=True)]
        self.biases = [np.random.randn(n_out) / np.sqrt(n_out) for n_out in sizes[1:]]

        self.G_weights = [np.zeros_like(w) for w in self.weights]
        self.G_biases = [np.zeros_like(b) for b in self.biases]


    def learning_step(self, x_mini_batch: FloatNDArray, y_mini_batch: FloatNDArray, learning_rate: float) -> None:
        grads_w, grads_b = self.backprop(x_mini_batch, y_mini_batch)

        for i in range(len(self.weights)):
            self.G_weights[i] += grads_w[i] ** 2
            self.G_biases[i] += grads_b[i] ** 2

        for i in range(len(self.weights)):
            self.weights[i] -= learning_rate * grads_w[i] / (np.sqrt(self.G_weights[i]) + self.epsilon)
            self.biases[i]  -= learning_rate * grads_b[i] / (np.sqrt(self.G_biases[i]) + self.epsilon)

        # for i, (gw, gb) in enumerate(zip(grads_w, grads_b)):
        #     w_norm = np.linalg.norm(gw)
        #     b_norm = np.linalg.norm(gb)
        #     print(f"Layer {i}: ||grad_w||={w_norm:.2e}, ||grad_b||={b_norm:.2e}")

model_results.evaluate_model(
    model_name=f"AdagradNetwork",
    model_constructor=AdagradNetwork,
    learning_rates=[0.01, 0.1, 0.5],
    n_trainings=1,
    layers=(784, 125, 30, 10)
  )
# Out:
# Checking 1 random trainings with with lr = 0.01
# Epoch: 100%|██████████| 10/10 [00:34<00:00,  3.41s/it, Test accuracy: 93.42 %]
# Checking 1 random trainings with with lr = 0.1
# Epoch: 100%|██████████| 10/10 [00:36<00:00,  3.62s/it, Test accuracy: 96.87 %]
# Checking 1 random trainings with with lr = 0.5
# Epoch: 100%|██████████| 10/10 [00:35<00:00,  3.54s/it, Test accuracy: 9.58 %]
